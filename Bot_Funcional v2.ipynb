# %% [markdown]
# <a href="https://colab.research.google.com/github/laribar/TechChallenge2/blob/main/Bot_Funcional%20v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ta
# !pip install yfinance
# Out:
# Collecting ta
#   Downloading ta-0.11.0.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from ta) (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from ta) (2.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->ta) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->ta) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->ta) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->ta) (1.17.0)
# Building wheels for collected packages: ta
#   Building wheel for ta (setup.py) ... done
#   Created wheel for ta: filename=ta-0.11.0-py3-none-any.whl size=29412 sha256=89781447a956299dbc4773aa90165464191f102e82839ab3b0c2f9c35d8c9cfa
#   Stored in directory: /root/.cache/pip/wheels/a1/d7/29/7781cc5eb9a3659d032d7d15bdd0f49d07d2b24fec29f44bc4
# Successfully built ta
# Installing collected packages: ta
# Successfully installed ta-0.11.0
# Requirement already satisfied: yfinance in /usr/local/lib/python3.11/dist-packages (0.2.55)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from yfinance) (2.2.2)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.11/dist-packages (from yfinance) (2.0.2)
# Requirement already satisfied: requests>=2.31 in /usr/local/lib/python3.11/dist-packages (from yfinance) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.11/dist-packages (from yfinance) (0.0.11)
# Requirement already satisfied: platformdirs>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from yfinance) (4.3.7)
# Requirement already satisfied: pytz>=2022.5 in /usr/local/lib/python3.11/dist-packages (from yfinance) (2025.1)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.11/dist-packages (from yfinance) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.11/dist-packages (from yfinance) (3.17.9)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.11/dist-packages (from yfinance) (4.13.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (4.12.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.3.0->yfinance) (2025.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31->yfinance) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31->yfinance) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31->yfinance) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31->yfinance) (2025.1.31)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)

# %%
import yfinance as yf
import numpy as np
import pandas as pd
import ta
import requests
import matplotlib.pyplot as plt
from datetime import datetime
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

# %%
# 1. Configurações
ASSETS = ASSETS = ["BTC-USD", "ETH-USD", "BNB-USD", "SOL-USD", "XRP-USD",
          "AVAX-USD", "AAVE-USD", "DOT-USD", "NEAR-USD", "ADA-USD", "SONIC-USD"]

TIMEFRAMES = [
    {"interval": "15m", "period": "30d", "atr": 0.02},
    {"interval": "1h", "period": "90d", "atr": 0.03},
    {"interval": "1d", "period": "1000d", "atr": 0.05}
]
TELEGRAM_TOKEN = "8044593190:AAFtUWYHd3uqd-AtQi3uqg42F9G6uV95v8k"
TELEGRAM_CHAT_ID = "-4744645054"

# 2. Obtenção de dados

def get_stock_data(asset, interval="15m", period="700d"):
    data = yf.download(asset, period=period, interval=interval, progress=False, auto_adjust=False)
    if isinstance(data.columns, pd.MultiIndex):
        data.columns = data.columns.get_level_values(0)
    data.columns = [col.split()[-1] if " " in col else col for col in data.columns]
    # Remove colunas duplicadas ou com sufixos como 'Adj Close'
    data = data.loc[:, ~data.columns.duplicated()]
    col_map = {}
    for col in data.columns:
        for std_col in ["Open", "High", "Low", "Close", "Adj Close", "Volume"]:
            if std_col.lower() in col.lower():
                col_map[col] = std_col
    data = data.rename(columns=col_map)
    # Garante que apenas as colunas necessárias estejam presentes
    data = data[["Open", "High", "Low", "Close", "Volume"]]
    required = ["Open", "High", "Low", "Close", "Volume"]
    if not all(col in data.columns for col in required):
        raise ValueError(f"⚠️ Dados de {asset} não possuem todas as colunas necessárias.")
    return data

# 3. Indicadores

def calculate_indicators(data):
    data = data.copy()
    data.reset_index(drop=True, inplace=True)

    for col in ["Open", "High", "Low", "Close", "Volume"]:
        if isinstance(data[col], pd.DataFrame):
            data[col] = data[col].iloc[:, 0]
        elif isinstance(data[col].iloc[0], (list, np.ndarray)):
            data[col] = data[col].apply(lambda x: x[0] if isinstance(x, (list, np.ndarray)) else x)
        data[col] = data[col].astype(float)

    # Indicadores
    data["RSI"] = ta.momentum.RSIIndicator(close=data["Close"], window=14).rsi()
    data["SMA_50"] = ta.trend.SMAIndicator(close=data["Close"], window=50).sma_indicator()
    data["SMA_200"] = ta.trend.SMAIndicator(close=data["Close"], window=200).sma_indicator()

    macd = ta.trend.MACD(close=data["Close"])
    data["MACD"] = macd.macd()
    data["MACD_Signal"] = macd.macd_signal()

    bb = ta.volatility.BollingerBands(close=data["Close"], window=20)
    data["Bollinger_Upper"] = bb.bollinger_hband()
    data["Bollinger_Lower"] = bb.bollinger_lband()

    adx = ta.trend.ADXIndicator(high=data["High"], low=data["Low"], close=data["Close"], window=14)
    data["ADX"] = adx.adx()

    stoch = ta.momentum.StochasticOscillator(high=data["High"], low=data["Low"], close=data["Close"], window=14)
    data["Stoch_K"] = stoch.stoch()
    data["Stoch_D"] = stoch.stoch_signal()

    data["TP"] = (data["High"] + data["Low"] + data["Close"]) / 3
    data["VWAP"] = (data["TP"] * data["Volume"]).cumsum() / (data["Volume"].replace(0, np.nan).cumsum())
    data.drop("TP", axis=1, inplace=True)

    data["Doji"] = ((abs(data["Close"] - data["Open"]) / (data["High"] - data["Low"] + 1e-9)) < 0.1).astype(int)
    data["Engulfing"] = ((data["Open"].shift(1) > data["Close"].shift(1)) & (data["Open"] < data["Close"]) &
                          (data["Close"] > data["Open"].shift(1)) & (data["Open"] < data["Close"].shift(1))).astype(int)
    data["Hammer"] = (((data["High"] - data["Low"]) > 3 * abs(data["Open"] - data["Close"])) &
                       ((data["Close"] - data["Low"]) / (data["High"] - data["Low"] + 1e-9) > 0.6) &
                       ((data["Open"] - data["Low"]) / (data["High"] - data["Low"] + 1e-9) > 0.6)).astype(int)

    data.dropna(inplace=True)
    return data



# 4. Modelo

def train_ml_model(data, verbose=False):
    if len(data) < 100:
        return None

    df = data.copy()

    # Sinal com base em retorno futuro
    df["Future_Close"] = df["Close"].shift(-5)
    df["Future_Return"] = df["Future_Close"] / df["Close"] - 1
    df["Signal"] = np.select([
        df["Future_Return"] > 0.015,
        df["Future_Return"] < -0.015
    ], [1, -1], default=0)

    features = get_feature_columns()
    df.dropna(inplace=True)
    X = df[features]
    y = df["Signal"]

    signal_count = (y == 1).sum()
    if verbose:
        print(f"📉 Sinais de COMPRA encontrados: {signal_count} em {len(y)} candles")

    if len(np.unique(y)) < 2:
        return None

    X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, shuffle=False)
    if len(np.unique(y_train)) < 2:
        return None

    model = RandomForestClassifier(n_estimators=200, max_depth=8, class_weight='balanced', random_state=42)
    model.fit(X_train, y_train)

    y_pred = model.predict(X_val)
    report = classification_report(y_val, y_pred, output_dict=True, zero_division=0)

    model.validation_score = {
        "accuracy": report.get("accuracy"),
        "precision": report.get("1", {}).get("precision"),
        "recall": report.get("1", {}).get("recall"),
        "f1": report.get("1", {}).get("f1-score")
    }

    # Log de importância das features
    feature_importances = dict(zip(features, model.feature_importances_))
    sorted_feat = sorted(feature_importances.items(), key=lambda x: x[1], reverse=True)
    print("\n📊 Importância das features:")
    for feat, score in sorted_feat[:5]:
        print(f"   {feat}: {score:.4f}")

    return model




# 5. Utilitários

def get_feature_columns():
    return [
        "RSI", "MACD", "MACD_Signal", "SMA_50", "SMA_200", "Bollinger_Upper",
        "Bollinger_Lower", "ADX", "Stoch_K", "Stoch_D", "VWAP",
        "Doji", "Engulfing", "Hammer"
    ]

def generate_explanation(row, prediction):
    explanation = []
    if prediction == 1:
        explanation.append("🟢 O modelo prevê uma tendência de ALTA.")
    elif prediction == -1:
        explanation.append("🔴 O modelo prevê uma tendência de BAIXA.")
    else:
        explanation.append("⚪ Sinal neutro.")

    if row["RSI"] < 30:
        explanation.append("🔽 RSI abaixo de 30 indica sobrevenda.")
    elif row["RSI"] > 70:
        explanation.append("🔼 RSI acima de 70 indica sobrecompra.")

    if row["SMA_50"] > row["SMA_200"]:
        explanation.append("📈 SMA 50 acima da 200, tendência de alta.")
    else:
        explanation.append("📉 SMA 50 abaixo da 200, tendência de baixa.")

    if row["MACD"] > row["MACD_Signal"]:
        explanation.append("💹 MACD cruzando para cima, possível reversão positiva.")
    else:
        explanation.append("🔻 MACD abaixo da linha de sinal.")

    if row["Doji"] == 1:
        explanation.append("⚠️ Padrão de candle Doji detectado (possível reversão).")

    if row["Engulfing"] == 1:
        explanation.append("📊 Padrão de engolfo detectado (sinal forte de reversão).")

    return "\n".join(explanation)

def calculate_targets(current_price, direction, atr=0.02):
    if direction == 1:
        return {
            "TP1": round(current_price * (1 + atr), 2),
            "TP2": round(current_price * (1 + atr * 2), 2),
            "SL": round(current_price * (1 - atr), 2)
        }
    elif direction == -1:
        return {
            "TP1": round(current_price * (1 - atr), 2),
            "TP2": round(current_price * (1 - atr * 2), 2),
            "SL": round(current_price * (1 + atr), 2)
        }
    else:
        return {"TP1": None, "TP2": None, "SL": None}

def send_telegram_message(message):
    url = f"https://api.telegram.org/bot{TELEGRAM_TOKEN}/sendMessage"
    payload = {"chat_id": TELEGRAM_CHAT_ID, "text": message, "parse_mode": "HTML"}
    requests.post(url, json=payload)
def predict_next_closes(data, n_steps=5):
  from sklearn.ensemble import RandomForestRegressor

  df = data.copy().reset_index(drop=True)
  features = get_feature_columns()
  df.dropna(inplace=True)

  X = df[features]
  y = df["Close"].shift(-1).dropna()
  X = X.loc[y.index]

  if len(X) < 100:
      return [None] * n_steps

  model = RandomForestRegressor(n_estimators=200, max_depth=8, random_state=42)
  model.fit(X, y)

  last_row = df[features].iloc[-1].copy()
  preds = []

  for step in range(n_steps):
      X_input = pd.DataFrame([last_row], columns=features)
      next_close = model.predict(X_input)[0]
      preds.append(round(next_close, 2))

      # Simula avanço do mercado
      last_row["Close"] = next_close
      if "SMA_50" in last_row:
          last_row["SMA_50"] = last_row["SMA_50"] * 0.9 + next_close * 0.1
      if "SMA_200" in last_row:
          last_row["SMA_200"] = last_row["SMA_200"] * 0.95 + next_close * 0.05
      if "VWAP" in last_row:
          last_row["VWAP"] = last_row["VWAP"] * 0.95 + next_close * 0.05
      if "RSI" in last_row:
          last_row["RSI"] = min(100, max(0, last_row["RSI"] + np.random.normal(0, 0.5)))
      if "MACD" in last_row:
          last_row["MACD"] += np.random.normal(0, 0.3)
      if "MACD_Signal" in last_row:
          last_row["MACD_Signal"] += np.random.normal(0, 0.2)

      last_row = last_row[features]

  return preds





# 6. Execução

def run_analysis():
    results = []

    for asset in ASSETS:
        print(f"\n📊 Analisando {asset}...")
        models = {}
        data = {}

        try:
            for tf in TIMEFRAMES:
                interval = tf['interval']
                period = tf['period']
                data[interval] = calculate_indicators(get_stock_data(asset, interval, period))
                models[interval] = train_ml_model(data[interval], verbose=True)
        except Exception as e:
            print(f"❌ Erro ao processar {asset}: {e}")
            continue

        if all(model is None for model in models.values()):
            print(f"⚠️ Nenhum modelo foi treinado para {asset}.")
            continue

        current_price = data["15m"]["Close"].iloc[-1]
        message = f"🔍 {asset}\n💰 Preço atual: ${current_price:.2f}\n"

        for tf in TIMEFRAMES:
            interval = tf['interval']
            model = models.get(interval)

            if model is None:
                message += f"\n⏱️ {interval}: Dados insuficientes para este timeframe.\n"
                continue

            latest_data = data[interval].iloc[-1]
            features = get_feature_columns()
            input_data = pd.DataFrame([latest_data[features]])
            prediction = model.predict(input_data)[0]
            proba = model.predict_proba(input_data)[0][np.where(model.classes_ == prediction)[0][0]]

            def safe_format(val): return f"{val:.2f}" if val is not None else "N/A"
            score = model.validation_score
            score_text = f"📈 Accuracy: {safe_format(score['accuracy'])} | Precision: {safe_format(score['precision'])} | Recall: {safe_format(score['recall'])}"

            targets = calculate_targets(current_price, prediction, tf['atr'])
            explanation = generate_explanation(latest_data, prediction)

            time_label = {"15m": "15 minutos", "1h": "1 hora", "1d": "Diário"}[interval]

            message += f"""
⏱️ {time_label}:
{'🟢 COMPRA' if prediction == 1 else ('🔴 VENDA' if prediction == -1 else '⚪ NEUTRO')} com {proba*100:.1f}% de confiança
🎯 TP1: ${targets['TP1']} | TP2: ${targets['TP2']} | SL: ${targets['SL']}
📌 Previsão: ${current_price * (1 + (tf['atr'] if prediction == 1 else (-tf['atr'] if prediction == -1 else 0))):.2f}
{score_text}
{explanation}
"""

            result = {
                "Asset": asset,
                "Timeframe": interval,
                "Date": latest_data.name,
                "Price": current_price,
                "Signal": prediction,
                "Confidence": round(proba, 4),
                "TP1": targets['TP1'],
                "TP2": targets['TP2'],
                "SL": targets['SL'],
                "Accuracy": score['accuracy'],
                "Precision": score['precision'],
                "Recall": score['recall'],
                "F1": score['f1']
            }

            # Previsão dos próximos 5 fechamentos (1h e 1d)
            if interval in ["1h", "1d"]:
                future_closes = predict_next_closes(data[interval])
                for i, val in enumerate(future_closes, 1):
                    label = f"Predicted_Close_t+{i}"
                    result[label] = val
                    print(f"📈 {label}: ${val}")

            results.append(result)

            try:
                df = data[interval].copy().tail(50)
                freq_map = {"15m": "15min", "1h": "h", "1d": "D"}
                freq = freq_map.get(interval, "1min")
                df["Datetime"] = (
                    df.index if isinstance(df.index, pd.DatetimeIndex)
                    else pd.date_range(end=pd.Timestamp.now(), periods=len(df), freq=freq)
                )
                plt.figure(figsize=(10, 4))
                plt.plot(df["Datetime"], df["Close"], label="Preço")
                if targets["TP1"]:
                    plt.axhline(targets['TP1'], color='green', linestyle='--', label='TP1')
                    plt.axhline(targets['TP2'], color='green', linestyle=':')
                    plt.axhline(targets['SL'], color='red', linestyle='--', label='SL')
                plt.title(f"{asset} - {interval.upper()} - Previsão: {'COMPRA' if prediction == 1 else 'VENDA' if prediction == -1 else 'NEUTRO'}")
                plt.legend()
                plt.xticks(rotation=45)
                plt.tight_layout()
                plt.grid()
                plt.show()
            except Exception as e:
                print(f"[!] Falha ao gerar gráfico: {e}")

            # Envio de alerta somente no timeframe diário com critério técnico ou confiança
            if interval == "1d" and (proba > 0.60 or ("MACD" in explanation and "SMA 50 acima" in explanation)):
                send_telegram_message(message)
                print(message)

    df_results = pd.DataFrame(results)
    timestamp = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
    filename = f"model_results_{timestamp}.csv"
    df_results.to_csv(filename, index=False)
    print(f"\n📁 Resultados salvos em: {filename}")

    # Backtest simples com TP1
    win_trades = df_results[(df_results['Signal'] == 1) & (df_results['Confidence'] > 0.6)]
    if not win_trades.empty:
        avg_target = (win_trades['TP1'] - win_trades['Price']).mean()
        print(f"\n✅ Backtest TP1 médio: +${avg_target:.2f} por trade em sinais de compra com confiança > 60%")
    else:
        print("\n⚠️ Nenhum trade de compra acima de 60% de confiança para backtest.")

    df_results = pd.DataFrame(results)
    timestamp = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
    filename = f"model_results_{timestamp}.csv"
    df_results.to_csv(filename, index=False)
    print(f"\n📁 Resultados salvos em: {filename}")

    # Backtest simples com TP1
    win_trades = df_results[(df_results['Signal'] == 1) & (df_results['Confidence'] > 0.6)]
    if not win_trades.empty:
        avg_target = (win_trades['TP1'] - win_trades['Price']).mean()
        print(f"\n✅ Backtest TP1 médio: +${avg_target:.2f} por trade em sinais de compra com confiança > 60%")
    else:
        print("\n⚠️ Nenhum trade de compra acima de 60% de confiança para backtest.")

# Execução em loop (a cada 1 hora)
import time

while True:
    print("🚀 Rodando a análise...")
    run_analysis()  # Chama sua função principal
    print("✅ Análise concluída. Aguardando 1 hora para a próxima execução...\n")
    time.sleep(3600)  # Aguarda 3600 segundos (1 hora)
# Out:
# 🚀 Rodando a análise...
#
# 📊 Analisando BTC-USD...
# 📉 Sinais de COMPRA encontrados: 64 em 2297 candles
#
# 📊 Importância das features:
#    VWAP: 0.1691
#    SMA_200: 0.1553
#    Bollinger_Lower: 0.0998
#    Bollinger_Upper: 0.0970
#    SMA_50: 0.0951
# 📉 Sinais de COMPRA encontrados: 152 em 927 candles
#
# 📊 Importância das features:
#    VWAP: 0.1264
#    SMA_200: 0.1243
#    Bollinger_Lower: 0.1220
#    SMA_50: 0.1164
#    Bollinger_Upper: 0.0887
# 📉 Sinais de COMPRA encontrados: 327 em 796 candles
#
# 📊 Importância das features:
#    Bollinger_Upper: 0.1113
#    VWAP: 0.1084
#    Bollinger_Lower: 0.1024
#    SMA_50: 0.1011
#    SMA_200: 0.0975
# 📈 Predicted_Close_t+1: $87383.17
# 📈 Predicted_Close_t+2: $87383.17
# 📈 Predicted_Close_t+3: $87383.17
# 📈 Predicted_Close_t+4: $87383.17
# 📈 Predicted_Close_t+5: $87383.17
# 📈 Predicted_Close_t+1: $87565.77
# 📈 Predicted_Close_t+2: $87565.77
# 📈 Predicted_Close_t+3: $87571.09
# 📈 Predicted_Close_t+4: $87571.09
# 📈 Predicted_Close_t+5: $87571.09
# 🔍 BTC-USD
# 💰 Preço atual: $87212.91
#
# ⏱️ 15 minutos:
# ⚪ NEUTRO com 57.7% de confiança
# 🎯 TP1: $None | TP2: $None | SL: $None
# 📌 Previsão: $87212.91
# 📈 Accuracy: 0.99 | Precision: 0.00 | Recall: 0.00
# ⚪ Sinal neutro.
# 📈 SMA 50 acima da 200, tendência de alta.
# 🔻 MACD abaixo da linha de sinal.
#
# ⏱️ 1 hora:
# ⚪ NEUTRO com 41.8% de confiança
# 🎯 TP1: $None | TP2: $None | SL: $None
# 📌 Previsão: $87212.91
# 📈 Accuracy: 0.25 | Precision: 0.17 | Recall: 1.00
# ⚪ Sinal neutro.
# 📈 SMA 50 acima da 200, tendência de alta.
# 🔻 MACD abaixo da linha de sinal.
#
# ⏱️ Diário:
# 🔴 VENDA com 53.7% de confiança
# 🎯 TP1: $82852.27 | TP2: $78491.62 | SL: $91573.56
# 📌 Previsão: $82852.27
# 📈 Accuracy: 0.33 | Precision: 0.85 | Recall: 0.17
# 🔴 O modelo prevê uma tendência de BAIXA.
# 📈 SMA 50 acima da 200, tendência de alta.
# 💹 MACD cruzando para cima, possível reversão positiva.
#
#
# 📊 Analisando ETH-USD...
# 📉 Sinais de COMPRA encontrados: 100 em 2421 candles
#
# 📊 Importância das features:
#    VWAP: 0.1584
#    SMA_200: 0.1411
#    SMA_50: 0.1141
#    Bollinger_Lower: 0.1087
#    Bollinger_Upper: 0.0953
# 📉 Sinais de COMPRA encontrados: 225 em 945 candles
#
# 📊 Importância das features:
#    Bollinger_Lower: 0.1089
#    VWAP: 0.1048
#    SMA_200: 0.1033
#    MACD_Signal: 0.0999
#    Bollinger_Upper: 0.0965
# 📉 Sinais de COMPRA encontrados: 318 em 796 candles
#
# 📊 Importância das features:
#    Bollinger_Lower: 0.1018
#    SMA_50: 0.0984
#    ADX: 0.0921
#    SMA_200: 0.0908
#    VWAP: 0.0896
# 📈 Predicted_Close_t+1: $2018.18
# 📈 Predicted_Close_t+2: $2018.18
# 📈 Predicted_Close_t+3: $2018.18
# 📈 Predicted_Close_t+4: $2018.18
# 📈 Predicted_Close_t+5: $2018.18
# 📈 Predicted_Close_t+1: $2004.63
# 📈 Predicted_Close_t+2: $2006.2
# 📈 Predicted_Close_t+3: $2006.2
# 📈 Predicted_Close_t+4: $2006.2
# 📈 Predicted_Close_t+5: $2006.2
# 📊 Analisando BNB-USD...
# 📉 Sinais de COMPRA encontrados: 62 em 2021 candles
#
# 📊 Importância das features:
#    VWAP: 0.1486
#    SMA_200: 0.1192
#    Bollinger_Upper: 0.1111
#    SMA_50: 0.0975
#    MACD_Signal: 0.0973
# 📉 Sinais de COMPRA encontrados: 183 em 936 candles
#
# 📊 Importância das features:
#    Bollinger_Lower: 0.1154
#    VWAP: 0.1145
#    SMA_50: 0.1078
#    SMA_200: 0.1017
#    Bollinger_Upper: 0.0968
# 📉 Sinais de COMPRA encontrados: 315 em 796 candles
#
# 📊 Importância das features:
#    SMA_200: 0.1091
#    VWAP: 0.1089
#    SMA_50: 0.1008
#    Bollinger_Upper: 0.0910
#    ADX: 0.0907
# 📈 Predicted_Close_t+1: $628.14
# 📈 Predicted_Close_t+2: $628.04
# 📈 Predicted_Close_t+3: $628.34
# 📈 Predicted_Close_t+4: $628.5
# 📈 Predicted_Close_t+5: $628.34
# 📈 Predicted_Close_t+1: $629.23
# 📈 Predicted_Close_t+2: $628.73
# 📈 Predicted_Close_t+3: $627.88
# 📈 Predicted_Close_t+4: $627.88
# 📈 Predicted_Close_t+5: $628.97
# 📊 Analisando SOL-USD...
# 📉 Sinais de COMPRA encontrados: 192 em 1747 candles
#
# 📊 Importância das features:
#    VWAP: 0.1393
#    SMA_200: 0.1337
#    Bollinger_Upper: 0.1266
#    SMA_50: 0.1172
#    Bollinger_Lower: 0.0965
# 📉 Sinais de COMPRA encontrados: 261 em 911 candles
#
# 📊 Importância das features:
#    VWAP: 0.1480
#    Bollinger_Lower: 0.1007
#    SMA_200: 0.0990
#    SMA_50: 0.0894
#    Bollinger_Upper: 0.0867
# 📉 Sinais de COMPRA encontrados: 375 em 796 candles
#
# 📊 Importância das features:
#    Bollinger_Upper: 0.1165
#    Bollinger_Lower: 0.1061
#    SMA_50: 0.0974
#    RSI: 0.0966
#    ADX: 0.0894
# 📈 Predicted_Close_t+1: $143.18
# 📈 Predicted_Close_t+2: $143.15
# 📈 Predicted_Close_t+3: $143.16
# 📈 Predicted_Close_t+4: $143.16
# 📈 Predicted_Close_t+5: $143.15
# 📈 Predicted_Close_t+1: $139.88
# 📈 Predicted_Close_t+2: $139.0
# 📈 Predicted_Close_t+3: $138.97
# 📈 Predicted_Close_t+4: $138.86
# 📈 Predicted_Close_t+5: $139.81
# 📊 Analisando XRP-USD...
# 📉 Sinais de COMPRA encontrados: 188 em 1775 candles
#
# 📊 Importância das features:
#    SMA_200: 0.1401
#    VWAP: 0.1282
#    Bollinger_Lower: 0.1103
#    SMA_50: 0.1015
#    Bollinger_Upper: 0.0944
# 📉 Sinais de COMPRA encontrados: 257 em 896 candles
#
# 📊 Importância das features:
#    VWAP: 0.1207
#    SMA_200: 0.1088
#    SMA_50: 0.1083
#    Bollinger_Lower: 0.0954
#    Bollinger_Upper: 0.0934
# 📉 Sinais de COMPRA encontrados: 308 em 796 candles
#
# 📊 Importância das features:
#    RSI: 0.0974
#    Bollinger_Upper: 0.0957
#    MACD_Signal: 0.0948
#    Bollinger_Lower: 0.0922
#    SMA_200: 0.0906
# 📈 Predicted_Close_t+1: $2.41
# 📈 Predicted_Close_t+2: $2.43
# 📈 Predicted_Close_t+3: $2.44
# 📈 Predicted_Close_t+4: $2.44
# 📈 Predicted_Close_t+5: $2.43
# 📈 Predicted_Close_t+1: $2.43
# 📈 Predicted_Close_t+2: $2.49
# 📈 Predicted_Close_t+3: $2.48
# 📈 Predicted_Close_t+4: $2.52
# 📈 Predicted_Close_t+5: $2.48
# 🔍 XRP-USD
# 💰 Preço atual: $2.43
#
# ⏱️ 15 minutos:
# ⚪ NEUTRO com 43.1% de confiança
# 🎯 TP1: $None | TP2: $None | SL: $None
# 📌 Previsão: $2.43
# 📈 Accuracy: 0.98 | Precision: 0.00 | Recall: 0.00
# ⚪ Sinal neutro.
# 📈 SMA 50 acima da 200, tendência de alta.
# 🔻 MACD abaixo da linha de sinal.
#
# ⏱️ 1 hora:
# ⚪ NEUTRO com 37.7% de confiança
# 🎯 TP1: $None | TP2: $None | SL: $None
# 📌 Previsão: $2.43
# 📈 Accuracy: 0.37 | Precision: 0.29 | Recall: 0.88
# ⚪ Sinal neutro.
# 📈 SMA 50 acima da 200, tendência de alta.
# 🔻 MACD abaixo da linha de sinal.
#
# ⏱️ Diário:
# 🔴 VENDA com 59.5% de confiança
# 🎯 TP1: $2.31 | TP2: $2.18 | SL: $2.55
# 📌 Previsão: $2.31
# 📈 Accuracy: 0.40 | Precision: 0.41 | Recall: 0.14
# 🔴 O modelo prevê uma tendência de BAIXA.
# 📈 SMA 50 acima da 200, tendência de alta.
# 💹 MACD cruzando para cima, possível reversão positiva.
#
#
# 📊 Analisando AVAX-USD...
# 📉 Sinais de COMPRA encontrados: 244 em 1897 candles
#
# 📊 Importância das features:
#    VWAP: 0.1279
#    SMA_200: 0.1218
#    SMA_50: 0.1154
#    Bollinger_Upper: 0.1115
#    Bollinger_Lower: 0.0987
# 📉 Sinais de COMPRA encontrados: 285 em 954 candles
#
# 📊 Importância das features:
#    VWAP: 0.1197
#    SMA_200: 0.1078
#    Bollinger_Upper: 0.1025
#    MACD_Signal: 0.0992
#    SMA_50: 0.0965
# 📉 Sinais de COMPRA encontrados: 334 em 796 candles
#
# 📊 Importância das features:
#    SMA_200: 0.1039
#    VWAP: 0.1014
#    Stoch_K: 0.0973
#    MACD_Signal: 0.0965
#    MACD: 0.0939
# 📈 Predicted_Close_t+1: $22.0
# 📈 Predicted_Close_t+2: $21.54
# 📈 Predicted_Close_t+3: $21.54
# 📈 Predicted_Close_t+4: $21.54
# 📈 Predicted_Close_t+5: $22.33
# 📈 Predicted_Close_t+1: $22.44
# 📈 Predicted_Close_t+2: $22.35
# 📈 Predicted_Close_t+3: $22.38
# 📈 Predicted_Close_t+4: $22.39
# 📈 Predicted_Close_t+5: $22.44
# 📊 Analisando AAVE-USD...
# 📉 Sinais de COMPRA encontrados: 250 em 1869 candles
#
# 📊 Importância das features:
#    SMA_200: 0.1418
#    VWAP: 0.1246
#    SMA_50: 0.1173
#    Bollinger_Upper: 0.1036
#    Bollinger_Lower: 0.0976
# 📉 Sinais de COMPRA encontrados: 295 em 946 candles
#
# 📊 Importância das features:
#    VWAP: 0.1227
#    Bollinger_Lower: 0.1131
#    SMA_50: 0.1067
#    SMA_200: 0.0999
#    Bollinger_Upper: 0.0930
# 📉 Sinais de COMPRA encontrados: 355 em 796 candles
#
# 📊 Importância das features:
#    Bollinger_Upper: 0.1037
#    SMA_200: 0.0995
#    Bollinger_Lower: 0.0993
#    VWAP: 0.0955
#    SMA_50: 0.0945
# 📈 Predicted_Close_t+1: $186.14
# 📈 Predicted_Close_t+2: $186.01
# 📈 Predicted_Close_t+3: $185.98
# 📈 Predicted_Close_t+4: $185.97
# 📈 Predicted_Close_t+5: $186.0
# 📈 Predicted_Close_t+1: $186.39
# 📈 Predicted_Close_t+2: $185.86
# 📈 Predicted_Close_t+3: $184.7
# 📈 Predicted_Close_t+4: $187.51
# 📈 Predicted_Close_t+5: $187.77
# 📊 Analisando DOT-USD...
# 📉 Sinais de COMPRA encontrados: 168 em 1798 candles
#
# 📊 Importância das features:
#    VWAP: 0.1303
#    SMA_50: 0.1195
#    Bollinger_Lower: 0.1106
#    Bollinger_Upper: 0.1050
#    MACD_Signal: 0.1032
# 📉 Sinais de COMPRA encontrados: 273 em 937 candles
#
# 📊 Importância das features:
#    VWAP: 0.1143
#    Bollinger_Upper: 0.1095
#    SMA_200: 0.1039
#    MACD_Signal: 0.1003
#    Bollinger_Lower: 0.0990
# 📉 Sinais de COMPRA encontrados: 324 em 796 candles
#
# 📊 Importância das features:
#    VWAP: 0.1010
#    Bollinger_Lower: 0.0987
#    SMA_200: 0.0964
#    ADX: 0.0956
#    SMA_50: 0.0933
# 📈 Predicted_Close_t+1: $4.68
# 📈 Predicted_Close_t+2: $4.75
# 📈 Predicted_Close_t+3: $4.76
# 📈 Predicted_Close_t+4: $4.76
# 📈 Predicted_Close_t+5: $4.76
# 📈 Predicted_Close_t+1: $4.71
# 📈 Predicted_Close_t+2: $4.68
# 📈 Predicted_Close_t+3: $4.72
# 📈 Predicted_Close_t+4: $4.72
# 📈 Predicted_Close_t+5: $4.72
# 📊 Analisando NEAR-USD...
# 📉 Sinais de COMPRA encontrados: 257 em 2023 candles
#
# 📊 Importância das features:
#    VWAP: 0.1456
#    SMA_200: 0.1159
#    Bollinger_Upper: 0.1113
#    MACD_Signal: 0.1013
#    SMA_50: 0.0985
# 📉 Sinais de COMPRA encontrados: 292 em 954 candles
#
# 📊 Importância das features:
#    VWAP: 0.1308
#    SMA_50: 0.1106
#    SMA_200: 0.1064
#    Bollinger_Upper: 0.1059
#    Bollinger_Lower: 0.1049
# 📉 Sinais de COMPRA encontrados: 334 em 796 candles
#
# 📊 Importância das features:
#    VWAP: 0.1094
#    SMA_50: 0.0993
#    Bollinger_Lower: 0.0983
#    SMA_200: 0.0971
#    Bollinger_Upper: 0.0961
# 📈 Predicted_Close_t+1: $3.02
# 📈 Predicted_Close_t+2: $3.07
# 📈 Predicted_Close_t+3: $3.05
# 📈 Predicted_Close_t+4: $3.07
# 📈 Predicted_Close_t+5: $3.07
# 📈 Predicted_Close_t+1: $3.07
# 📈 Predicted_Close_t+2: $3.52
# 📈 Predicted_Close_t+3: $3.11
# 📈 Predicted_Close_t+4: $3.45
# 📈 Predicted_Close_t+5: $3.58
# 📊 Analisando ADA-USD...
# 📉 Sinais de COMPRA encontrados: 209 em 1744 candles
#
# 📊 Importância das features:
#    VWAP: 0.1450
#    Bollinger_Upper: 0.1285
#    SMA_200: 0.1167
#    Bollinger_Lower: 0.1113
#    SMA_50: 0.1067
# 📉 Sinais de COMPRA encontrados: 279 em 897 candles
#
# 📊 Importância das features:
#    SMA_200: 0.1187
#    SMA_50: 0.1154
#    Bollinger_Upper: 0.1070
#    VWAP: 0.1018
#    Bollinger_Lower: 0.1002
# 📉 Sinais de COMPRA encontrados: 317 em 796 candles
#
# 📊 Importância das features:
#    Bollinger_Upper: 0.0995
#    VWAP: 0.0992
#    SMA_200: 0.0946
#    ADX: 0.0935
#    Bollinger_Lower: 0.0929
# 📈 Predicted_Close_t+1: $0.76
# 📈 Predicted_Close_t+2: $0.72
# 📈 Predicted_Close_t+3: $0.77
# 📈 Predicted_Close_t+4: $0.77
# 📈 Predicted_Close_t+5: $0.75
# 📈 Predicted_Close_t+1: $0.72
# 📈 Predicted_Close_t+2: $0.74
# 📈 Predicted_Close_t+3: $0.74
# 📈 Predicted_Close_t+4: $0.74
# 📈 Predicted_Close_t+5: $0.74
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['SONIC-USD']: YFPricesMissingError('possibly delisted; no price data found  (period=30d)')
# 🔍 ADA-USD
# 💰 Preço atual: $0.75
#
# ⏱️ 15 minutos:
# ⚪ NEUTRO com 53.8% de confiança
# 🎯 TP1: $None | TP2: $None | SL: $None
# 📌 Previsão: $0.75
# 📈 Accuracy: 0.84 | Precision: 0.00 | Recall: 0.00
# ⚪ Sinal neutro.
# 📈 SMA 50 acima da 200, tendência de alta.
# 🔻 MACD abaixo da linha de sinal.
#
# ⏱️ 1 hora:
# 🟢 COMPRA com 45.8% de confiança
# 🎯 TP1: $0.77 | TP2: $0.8 | SL: $0.73
# 📌 Previsão: $0.77
# 📈 Accuracy: 0.39 | Precision: 0.31 | Recall: 0.59
# 🟢 O modelo prevê uma tendência de ALTA.
# 📈 SMA 50 acima da 200, tendência de alta.
# 🔻 MACD abaixo da linha de sinal.
#
# ⏱️ Diário:
# 🔴 VENDA com 67.4% de confiança
# 🎯 TP1: $0.71 | TP2: $0.68 | SL: $0.79
# 📌 Previsão: $0.71
# 📈 Accuracy: 0.47 | Precision: 0.45 | Recall: 0.21
# 🔴 O modelo prevê uma tendência de BAIXA.
# 📈 SMA 50 acima da 200, tendência de alta.
# 💹 MACD cruzando para cima, possível reversão positiva.
#
#
# 📊 Analisando SONIC-USD...
# ❌ Erro ao processar SONIC-USD: single positional indexer is out-of-bounds
#
# 📁 Resultados salvos em: model_results_2025-03-26_14-11-48.csv
#
# ⚠️ Nenhum trade de compra acima de 60% de confiança para backtest.
#
# 📁 Resultados salvos em: model_results_2025-03-26_14-11-48.csv
#
# ⚠️ Nenhum trade de compra acima de 60% de confiança para backtest.
# ✅ Análise concluída. Aguardando 1 hora para a próxima execução...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-34-57fa89e82967> in <cell line: 0>()
#     396     run_analysis()  # Chama sua função principal
#     397     print("✅ Análise concluída. Aguardando 1 hora para a próxima execução...\n")
# --> 398     time.sleep(3600)  # Aguarda 3600 segundos (1 hora)
#
# KeyboardInterrupt:
